# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient 
from pprint import pprint 
import pandas as pd

# %%
# Create an instance of MongoClient

mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created

print(mongo.list_database_names())
# Out:
# ['admin', 'config', 'local', 'travel_db', 'uk_food']

# %%
# assign the uk_food database to a variable name

db = mongo['uk_food']

# %%
# review the collections in our database

print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20

query = {'scores.Hygiene': 20}

# Use count_documents to display the number of documents in the result
num_documents = establishments.count_documents(query)
print(f'num_documents: {num_documents}\n')

# Display the first document in the results using pprint
results = establishments.find(query)
pprint(results[0])
# Out:
# num_documents: 41
#
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': '0',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6428b234b5235eaf07754836'),
#  'geocode': {'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
# ...

# %%
# Convert the result to a Pandas DataFrame
hygiene_20_df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print(f'num rows: {hygiene_20_df.shape[0]}\n')
# Display the first 10 rows of the DataFrame
hygiene_20_df.head(10)
# Out:
# num rows: 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  6428b234b5235eaf07754836   110681                  0
# 1  6428b234b5235eaf07754bb8   612039                  0
# 2  6428b234b5235eaf07754ecd   730933                  0
# 3  6428b234b5235eaf077550b1   172735                  0
# 4  6428b234b5235eaf077550c5   172953                  0
# 5  6428b234b5235eaf07755a5d   512854                  0
# 6  6428b234b5235eaf07755c80  1537089                  0
# 7  6428b234b5235eaf077571ad   155648                  0
# 8  6428b234b5235eaf077575f6  1012883                  0
# 9  6428b234b5235eaf07757dff   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
#There is no london
establishments.distinct('AddressLine3')
# Out:
# ['',
#  '1 - 2 Davy Road',
#  '1 - 7 Commercial Road',
#  '1 Dock Road',
#  '1 Elmfield Park',
#  '1 Hallsville Road',
#  '1 High Street',
#  '1 Robin Hood Lane',
#  '1 St Nicholas Passage',
#  '1 St Runwald Street',
#  '1 Triangle Shopping Centre',
#  '1 Western Gateway',
#  '1-2 Sparrow Way',
#  '1-5 Harvey Centre Approach',
#  '10 - 12 Commercial Road',
#  '10 Canterbury Road',
#  '100 Third Avenue',
#  '1000 Dockside Road',
#  '103 - 107 York Road',
#  '103 Maidstone Road',
#  '105 Hopewell Drive',
#  '106 Pattens Lane',
#  '109 Tollgate Road',
#  '11 Oxford Road',
#  '11A North Hill',
#  '123 Star Lane',
#  '129-139 Layer Road',
#  '13 Eridge Road',
#  '13 High Street',
#  '14 Fox Burrows Lane',
#  '14 Turners Place',
#  '14 Western Gateway',
#  '143 Church Street',
#  '147 Station Road',
#  '15 Corys Road',
#  '15 The Grove',
#  '15A-16 New Road Avenue',
#  '16 Victoria Road',
#  '17 Market Buildings',
#  '18 New Road Avenue',
#  '186 High Street',
#  '189 Romford Road',
# ...

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {'AddressLine3': 'London', 'RatingValue': {'$gte': '4'}}

# Use count_documents to display the number of documents in the result
num_documents = establishments.count_documents(query)
print(f'num_documents: {num_documents}\n')

# Display the first document in the results using pprint
results = establishments.find(query)
pprint(results[0])
# Out:
# num_documents: 1157
#
# {'AddressLine1': '',
#  'AddressLine2': '29-32 The Oval',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'The Mallow Man',
#  'BusinessType': 'Takeaway/sandwich shop',
#  'BusinessTypeID': 7844,
#  'ChangesByServerID': 0,
#  'Distance': 4645.039576588197,
#  'FHRSID': 1474745,
#  'LocalAuthorityBusinessID': '208757',
#  'LocalAuthorityCode': '530',
#  'LocalAuthorityEmailAddress': 'foodsafety@towerhamlets.gov.uk',
#  'LocalAuthorityName': 'Tower Hamlets',
#  'LocalAuthorityWebSite': 'http://www.towerhamlets.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '1901-01-01T00:00:00',
#  'RatingKey': 'fhrs_awaitinginspection_en-gb',
#  'RatingValue': 'AwaitingInspection',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6428b235b5235eaf07759775'),
#  'geocode': {'latitude': Decimal128('51.4451165'),
#              'longitude': Decimal128('0.1024387')},
# ...

# %%
# Convert the result to a Pandas DataFrame
london_rating_df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
print(f'num rows: {london_rating_df.shape[0]}\n')
# Display the first 10 rows of the DataFrame
london_rating_df.head(10)
# Out:
# num rows: 1157
#                         _id   FHRSID  ChangesByServerID  \
# 0  6428b235b5235eaf07759775  1474745                  0
# 1  6428b235b5235eaf07759818   329114                  0
# 2  6428b235b5235eaf07759822   329113                  0
# 3  6428b235b5235eaf07759975  1402880                  0
# 4  6428b235b5235eaf07759a19  1262185                  0
# 5  6428b235b5235eaf07759a1e   975472                  0
# 6  6428b235b5235eaf07759b87   687040                  0
# 7  6428b235b5235eaf07759b95   610394                  0
# 8  6428b235b5235eaf07759bf4  1109051                  0
# 9  6428b235b5235eaf07759c20  1385124                  0
#
#   LocalAuthorityBusinessID                                       BusinessName  \
# 0                   208757                                     The Mallow Man
# 1         03260/2001/2/000                     Belvedere Sports & Social Club
# 2         03260/0075/0/000                              The Croft Day Nursery
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of '5', sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
penang_query = {'BusinessName': 'Penang Flavours'}
results = establishments.find(penang_query)
pprint(results[0])
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6429f1c56b88299b3c04854e'),
#  'geocode': {'latitude': Decimal128('51.49014200'),
#              'longitude': Decimal128('0.08384000')},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5

degree_search = 0.01
latitude = float(str(results[0]['geocode']['latitude']))
longitude = float(str(results[0]['geocode']['longitude']))

query = {'geocode.latitude' : {'$gte' :latitude - degree_search, '$lte' : latitude + degree_search},
         'geocode.longitude' : {'$gte' :longitude - degree_search, '$lte' : longitude + degree_search},
         'RatingValue': '5'}

results_coordinates = establishments.find(query)

# Print the results
for i in range(3):
    pprint(results_coordinates[i])
# Out:
# {'AddressLine1': '152 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'TIWA N TIWA African Restaurant Ltd',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4646.930146257832,
#  'FHRSID': 1069652,
#  'LocalAuthorityBusinessID': 'PI/000206841',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1JQ',
#  'RatingDate': '2020-10-24T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6428b235b5235eaf0775a042'),
#  'geocode': {'latitude': Decimal128('51.4870351'),
#              'longitude': Decimal128('0.0927429')},
# ...

# %%
# Sort by hygiene score'

sort = [('scores.hygiene', 1)]
sort_results = establishments.find(query).sort(sort)

# Print the results
for i in range(5):
    pprint(sort_results[i])
# Out:
# {'AddressLine1': '152 Plumstead High Street',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'TIWA N TIWA African Restaurant Ltd',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'ChangesByServerID': 0,
#  'Distance': 4646.930146257832,
#  'FHRSID': 1069652,
#  'LocalAuthorityBusinessID': 'PI/000206841',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1JQ',
#  'RatingDate': '2020-10-24T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6428b235b5235eaf0775a042'),
#  'geocode': {'latitude': Decimal128('51.4870351'),
#              'longitude': Decimal128('0.0927429')},
# ...

# %%
# Convert result to Pandas DataFrame

sort_results_df = pd.DataFrame(sort_results)
sort_results_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  6428b235b5235eaf0775a042  1069652                  0
# 1  6428b235b5235eaf0775a06e   695223                  0
# 2  6428b235b5235eaf0775a081  1380578                  0
# 3  6428b235b5235eaf0775a098   694609                  0
# 4  6428b235b5235eaf0775a0b1   695241                  0
# 5  6428b235b5235eaf0775a0b3   694478                  0
# 6  6428b235b5235eaf0775a0b5   909912                  0
# 7  6428b235b5235eaf0775a0d5   695204                  0
# 8  6428b235b5235eaf0775a0d7   694482                  0
# 9  6428b235b5235eaf0775a0fc  1211907                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000206841   TIWA N TIWA African Restaurant Ltd
# 1             PI/000178842                              Iceland
# 2                    14425  Howe and Co Fish and Chips - Van 17
# 3             PI/000116619                            Volunteer
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
match_query = {'$match': {'scores.Hygiene': 0}}

# 2. Groups the matches by Local Authority
group_query = {'$group': {'_id': '$LocalAuthorityName', 'count': {'$sum': 1}}}

# 3. Sorts the matches from highest to lowest
sort_values = {'$sort': {'count': -1}}
pipeline = [match_query, group_query, sort_values]

# Print the number of documents in the result
results = list(establishments.aggregate(pipeline)) 
# Print the first 10 results
print("Number of establishments in result: ", len(results)) 
pprint(results[0:10])
# Out:
# Number of establishments in result:  55
# [{'_id': 'Thanet', 'count': 1130},
#  {'_id': 'Greenwich', 'count': 882},
#  {'_id': 'Maidstone', 'count': 713},
#  {'_id': 'Newham', 'count': 711},
#  {'_id': 'Swale', 'count': 686},
#  {'_id': 'Chelmsford', 'count': 680},
#  {'_id': 'Medway', 'count': 672},
#  {'_id': 'Bexley', 'count': 607},
#  {'_id': 'Southend-On-Sea', 'count': 586},
#  {'_id': 'Tendring', 'count': 542}]

# %%
# Convert the result to a Pandas DataFrame
result_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
print("Rows in DataFrame: ", len(result_df))
# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
# Rows in DataFrame:  55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
